# %% [markdown]
# draw multilpe bar in one chart

# %%
from matplotlib import color_sequences
import matplotlib.pyplot as plt
pcm = plt.bar( ["hindi","english","math"],  [90,100,85],color = ["pink","yellow","green"],width = 0.8,)
bio = plt.bar( ["phy","che","bio"],  [75,95,80],color =  ["pink","yellow","green"],width = 0.8)
sst = plt.bar( ["history","geo","polity"],  [70,105,65],color =  ["pink","yellow","green"],width = 0.8)
plt.xlabel("subjects",fontsize = 20)
plt.ylabel("marks" , fontsize = 20)
plt.grid("true",color = "black")
plt.title("marksheet",fontsize = 20)
plt.show()
